# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedZaid-AI/Data-Structures-and-algo/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2026-04-06 211914.png](data:image/png;base64,...)

# %% [markdown]
# Think of this code as a smart search. Imagine you are at a party, and you need to find two people whose ages add up to exactly 50.
# Instead of asking every person to pair up with every other person (which would take forever), you walk through the room once with a notebook.
# ------------------------------
# ## The "Notebook" Strategy (Line-by-Line)
#
#    1. num_to_index = {} (The Notebook)
#    * This is your empty notebook (a Python dictionary).
#       * You’ll use it to write down: "I saw the number X at position Y."
#    2. for i, num in enumerate(arr): (Walking the Room)
#    * You walk through the list one by one.
#       * num is the number you are looking at right now.
#       * i is its "seat number" (index) in the list.
#    3. complement = target - num (The Missing Piece)
#    * If your goal is 10 and the current number is 7, you know you need a 3 to win.
#       * complement is that "missing piece" ($10 - 7 = 3$).
#    4. if complement in num_to_index: (Checking the Notebook)
#    * This is the most important part. You check your notebook: "Have I already seen a 3 earlier in this walk?"
#       * Because it's a HashMap/Dictionary, Python can check this almost instantly, no matter how big the notebook is.
#    5. return [num_to_index[complement], i] (The Success)
#    * If you did see a 3 earlier, you’re done!
#       * You return the seat number of the 3 (which you stored in the notebook) and your current seat number i.
#    6. num_to_index[num] = i (Writing it Down)
#    * If you haven't seen the "missing piece" yet, you don't give up.
#       * You write your own number and seat number in the notebook: num_to_index[7] = index. Now, if someone later needs a 7, they will find you in the notebook!
#
# ------------------------------
# ## Why is this better than a normal search?
# If you didn't have the notebook, you would have to:
#
#    1. Pick the first number.
#    2. Scan the entire rest of the list for its partner.
#    3. Pick the second number.
#    4. Scan the entire rest of the list again.
#
# That's like looking at every person in the room over and over. With the Dictionary (HashMap), you only look at each person once.
# ## A Quick Example
# List: [2, 7, 11] | Target: 9
#
# * Step 1 (Number 2): Target is 9. I need a 7. Is 7 in my notebook? No.
# * Notebook now says: {2: 0}
# * Step 2 (Number 7): Target is 9. I need a 2. Is 2 in my notebook? Yes!
# * Result: Return index of 2 (which is 0) and current index (which is 1). Result: [0, 1].
#
# ------------------------------
# Would you like to try writing a small change to this code, like making it return the actual numbers instead of the indices?

# %% [markdown]
# Short answer: No, complement is a value (a number), not an index.
# However, we use that value to look up an index in our dictionary. Here is the distinction:
# ## 1. The Value (complement)
# complement is just the "missing piece" of math.
#
# * If your Target is 10 and your current Number is 7...
# * The complement is 3 ($10 - 7 = 3$).
# * It is a pure number, not a position.
#
# ## 2. The Index (num_to_index[complement])
# The dictionary (num_to_index) is like a map that links Values to Indices.
#
# * Key: The number we saw before (e.g., 3).
# * Value: Where we saw it (e.g., Index 0).
#
# ------------------------------
# ## See it in action:
# Look at line 8 in the code:
# return [num_to_index[complement], i]
#
# * complement: "I am looking for the number 3."
# * num_to_index[complement]: "The notebook says the number 3 was found at Index 0."
# * i: "I am currently at Index 1."
#
# So the code returns [0, 1].
# ## Summary Table
#
# | Variable | What it is | Example |
# |---|---|---|
# | num | The current number in the list | 7 |
# | i | The current index (seat number) | 1 |
# | complement | The value we need to find | 3 |
# | num_to_index[complement] | The index where that value lives | 0 |
#
# Does it make sense why we use the value to find the index, or would you like to see what the dictionary looks like "under the hood" at each step?

# %% [markdown]
# ![Screenshot 2026-04-06 215652.png](data:image/png;base64,...)

# %% [markdown]
# ## **TWO POINTERS**

# %% [markdown]
# The Two Pointers in the same direction technique is an algorithmic pattern where two indices (pointers) traverse a data structure—typically an array, string, or linked list—from the same starting point and move towards the same end. This approach is primarily used to optimize solutions from a brute-force $O(n^2)$ time complexity down to $O(n)$ by avoiding nested loops. [1, 2, 3, 4, 5, 6]
#
# [Two Pointers (Same Direction) - DEV Community](https://dev.to/jayaprasanna_roddam/two-pointers-same-direction-39i)
# [Algorithms - Two Pointers Template That Solves Many Problems ...](https://shawn-shi.medium.com/summary-notes-on-algorithms-two-pointers-c81735def5b2)
# [Two Pointers Approach - Python Code | Towards Data Science](https://towardsdatascience.com/two-pointer-approach-python-code-f3986b602640/)
#
# ## Core Variations
# This technique generally splits into three main strategies based on how the pointers move relative to each other: [1]
#
# * Fast and Slow Pointers: One pointer (fast) moves at a higher speed or constant increment, while the other (slow) only moves when specific conditions are met.
# * Use cases: Detecting cycles in linked lists (Floyd’s Cycle-Finding Algorithm), finding the middle of a list, or removing duplicates in-place.
# * Sliding Window: Both pointers define the boundaries of a contiguous "window" of elements. The "right" pointer expands the window to include new elements, while the "left" pointer contracts it to maintain certain constraints.
# * Use cases: Finding the longest substring without repeating characters, minimum size subarray sum, or fixed-size maximum sum subarrays.
# * Read/Write Pointers (Staged Traversal): One pointer "reads" or scans for valid data, while the other "writes" or marks the position for the next valid element to be placed.
# * Use cases: Moving all zeros to the end of an array or in-place memory compaction in garbage collection. [1, 3, 4, 6, 7, 8, 9, 10]
#
# ## When to Use This Pattern
# You should consider same-direction pointers if your problem involves: [11]
#
#    1. Contiguous Segments: The task asks for a subarray, substring, or consecutive segment.
#    2. Optimization: You need to find the "longest," "shortest," "maximum," or "minimum" length that satisfies a condition.
#    3. Linear Traversal: The goal is $O(n)$ time and $O(1)$ extra space.
#    4. Linked List Structure: Determining properties like cycles or specific nodes (e.g., $n$-th node from the end). [3, 4, 6, 7, 12, 13]
#
# ## Comparison with Other Patterns
# Unlike Opposite Direction pointers (where pointers start at each end and meet in the middle for things like palindromes or two-sum on sorted arrays), same-direction pointers never "squeeze" the data; they "sweep" across it. [1, 14, 15, 16, 17]
# ------------------------------
# ## Further Exploration
#
# * Learn how to identify various [Two Pointer Patterns](https://medium.com/@priyankabhat2468/dsa-pattern-1-two-pointers-simplified-e01febfba1ff) including partitioning and converging styles from Priyanka Bhat on Medium.
# * Explore technical deep-dives into [Same Direction Two Pointers](https://lakshmimishra.medium.com/same-direction-two-pointers-d2ac76c1866f) with a focus on sliding windows by Lakshmi Mishra.
# * Watch a visual explanation of [Fast and Slow Pointers](https://www.youtube.com/watch?v=G5cC3WbUQ7E) for cycle detection on YouTube.
# * Read about the [Sliding Window variation](https://usaco.guide/silver/two-pointers) and its application in competitive programming from the USACO Guide. [18, 19, 20]
#
# Would you like to see a code implementation for a specific problem like "Remove Duplicates" or "Longest Substring"?bolding
#
# [1] [https://bytebytego.com](https://bytebytego.com/courses/coding-patterns/two-pointers/introduction-to-two-pointers?fpr=javarevisited)
# [2] [https://dev.to](https://dev.to/charlesamakoye/dissecting-the-two-pointer-technique-2lb4)
# [3] [https://medium.com](https://medium.com/@priyankabhat2468/dsa-pattern-1-two-pointers-simplified-e01febfba1ff)
# [4] [https://lakshmimishra.medium.com](https://lakshmimishra.medium.com/same-direction-two-pointers-d2ac76c1866f)
# [5] [https://www.codechef.com](https://www.codechef.com/practice/two-pointers)
# [6] [https://medium.com](https://medium.com/@meghanathota13/mastering-the-two-pointers-technique-three-essential-approaches-with-code-examples-bc785b09cbc3)
# [7] [https://www.youtube.com](https://www.youtube.com/watch?v=G5cC3WbUQ7E)
# [8] [https://medium.com](https://medium.com/@Prachi-Jamdade/two-pointers-algorithm-most-efficient-technique-to-optimize-runtime-fbbbf24a3891)
# [9] [https://www.youtube.com](https://www.youtube.com/watch?v=rQhNcycbf8w&t=174)
# [10] [https://usaco.guide](https://usaco.guide/silver/two-pointers)
# [11] [https://medium.com](https://medium.com/@fidanalizada95/two-pointers-how-to-reduce-time-from-o-n%C2%B2-to-o-n-without-extra-space-5b18ee3b6792#:~:text=The%20core%20idea%20of%20the%20technique%20is,pattern%29%2C%20ortoward%20each%20other%20%28opposite%20direction%20pattern%29.)
# [12] [https://vetswhocode.io](https://vetswhocode.io/blogs/two-pointers-a-practical-technique-for-code-challenges)
# [13] [https://www.youtube.com](https://www.youtube.com/watch?v=QzZ7nmouLTI&t=45)
# [14] [https://www.youtube.com](https://www.youtube.com/watch?v=syTs9_w-pwA)
# [15] [https://www.instagram.com](https://www.instagram.com/reel/DWbYe5FDAQs/#:~:text=00%20rupees%20challenge%20exact%20two%20items%20five,pointer%20five%20right%20pointer%2080%20some%2085)
# [16] [https://smartprogramming.in](https://smartprogramming.in/tutorials/dsa-using-java/two-pointers-technique)
# [17] [https://algo.monster](https://algo.monster/problems/two_pointers_intro)
# [18] [https://www.linkedin.com](https://www.linkedin.com/pulse/recognizing-mastering-codingpatterns-part-1-two-pointer-bhatia-nlpuf#:~:text=Understanding%20patterns%20like%20the%20two%2Dpointer%20technique%20is,to%20approach%20problems%20with%20confidence%20and%20efficiency.)
# [19] [https://www.instagram.com](https://www.instagram.com/reel/DT4itV8E-21/)
# [20] [https://medium.com](https://medium.com/@srihithamaradi1998/have-you-ever-been-asked-in-a-coding-interview-to-detect-a-loop-in-a-linked-list-1584a9a65a95)

# %% [markdown]
# The Same Direction Two Pointers technique is used primarily to optimize array and string traversals, reducing time complexity from $O(n^2)$ to $O(n)$. It is applied when you need to maintain a relationship between two indices that both progress from the start of a data structure to the end. [1, 2, 3]
# ## Key Uses and Strategies
# This technique is categorized into three distinct operational patterns:
#
# * Sliding Window (Dynamic & Fixed): Used when you need to find a contiguous subarray or substring that meets specific criteria.
# * Fixed Window: The pointers maintain a constant distance (e.g., finding the maximum sum of any $K$ consecutive elements).
#    * Dynamic Window: The window expands with the "right" pointer and contracts with the "left" pointer based on a condition (e.g., "at most $K$ distinct characters").
# * Fast and Slow Pointers (Tortoise and Hare): Pointers move at different speeds (usually one moves twice as fast) to detect structural properties.
# * Cycle Detection: Determining if a linked list or sequence has a loop.
#    * Middle Element: Finding the midpoint of a linked list in a single pass.
# * Read/Write (Staged Traversal): One pointer "reads" the input while the other "writes" to a specific position to modify the data in-place.
# * Filtering: Removing duplicates or specific elements without using extra space.
#    * Memory Compaction: In garbage collection, a "scan" pointer identifies live objects while a "free" pointer marks the next available space to shift them. [1, 2, 4, 5, 6, 7, 8, 9, 10, 11, 12]
#
# ## Common Interview Applications
#
# | Problem Category [2, 6, 7, 13, 14, 15] | Specific Application Examples |
# |---|---|
# | String Manipulation | Longest substring without repeating characters. |
# | Subarray Optimization | Smallest subarray with a sum greater than or equal to $K$. |
# | In-place Modification | Moving all zeros to the end of an array while maintaining order. |
# | Linked List Analysis | Finding the $N$-th node from the end of a list. |
# | Array Partitioning | Sorting an array of 0s, 1s, and 2s (Dutch National Flag problem). |
#
# ------------------------------
# ## Further Exploration
#
# * Review a comprehensive list of [Top Two Pointer Problems](https://www.geeksforgeeks.org/dsa/top-problems-on-two-pointers-technique-for-interviews/) for interview prep on GeeksforGeeks.
# * Watch a detailed visual guide on the [Sliding Window Technique](https://www.youtube.com/watch?v=dOonV4byDEg) from YouTube to understand $O(n)$ optimization.
# * Explore the [Staged Traversal strategy](https://bytebytego.com/courses/coding-patterns/two-pointers/introduction-to-two-pointers?fpr=javarevisited) and its use in garbage collection algorithms on ByteByteGo.
# * Learn how [Fast and Slow Pointers](https://www.youtube.com/watch?v=b139yf7Ik-E) find the middle of a linked list in one pass on YouTube. [12, 16, 17]
#
# Would you like to try a step-by-step walkthrough of a specific application, such as finding the longest unique substring?
#
# [1] [https://bytebytego.com](https://bytebytego.com/courses/coding-patterns/two-pointers/introduction-to-two-pointers?fpr=javarevisited)
# [2] [https://lakshmimishra.medium.com](https://lakshmimishra.medium.com/same-direction-two-pointers-d2ac76c1866f)
# [3] [https://lakshmimishra.medium.com](https://lakshmimishra.medium.com/same-direction-two-pointers-d2ac76c1866f)
# [4] [https://www.youtube.com](https://www.youtube.com/watch?v=MQmUVokbTrs&t=728)
# [5] [https://www.youtube.com](https://www.youtube.com/watch?v=dOonV4byDEg)
# [6] [https://www.youtube.com](https://www.youtube.com/watch?v=y2d0VHdvfdc&t=236)
# [7] [https://www.youtube.com](https://www.youtube.com/watch?v=G5cC3WbUQ7E)
# [8] [https://www.youtube.com](https://www.youtube.com/watch?v=XWyXy2aNrXM)
# [9] [https://www.instagram.com](https://www.instagram.com/reel/DT4itV8E-21/)
# [10] [https://www.youtube.com](https://www.youtube.com/watch?v=b139yf7Ik-E&t=170)
# [11] [https://www.interviewbit.com](https://www.interviewbit.com/courses/programming/two-pointers/)
# [12] [https://bytebytego.com](https://bytebytego.com/courses/coding-patterns/two-pointers/introduction-to-two-pointers?fpr=javarevisited)
# [13] [https://www.geeksforgeeks.org](https://www.geeksforgeeks.org/dsa/two-pointers-technique/)
# [14] [https://www.geeksforgeeks.org](https://www.geeksforgeeks.org/dsa/top-problems-on-two-pointers-technique-for-interviews/)
# [15] [https://www.youtube.com](https://www.youtube.com/watch?v=QzZ7nmouLTI&t=45)
# [16] [https://www.youtube.com](https://www.youtube.com/watch?v=DjYZk8nrXVY&t=113)
# [17] [https://www.youtube.com](https://www.youtube.com/watch?v=G5cC3WbUQ7E)

# %% [markdown]
# This code solves the "Valid Palindrome" problem. While our previous discussion focused on pointers moving in the same direction, this specific implementation uses Opposite Direction Two Pointers.
# The goal is to check if a string is a palindrome while ignoring non-alphanumeric characters (like spaces, commas, or periods) and ignoring case.
# ------------------------------
# ## 1. The Setup (Line 2)
#
# l, r = 0, len(s) - 1
#
#
# * l (Left pointer): Starts at the first character (index 0).
# * r (Right pointer): Starts at the last character (index length - 1).
# * Think of these as two scouts starting at opposite ends of a bridge and walking toward each other to meet in the middle.
#
# ## 2. The Main Loop (Line 3)
#
# while l < r:
#
# The logic continues only as long as the left pointer is to the left of the right pointer. If they meet or cross, it means every pair of characters has been checked and matched successfully.
# ## 3. Skipping "Noise" (Lines 4-7)
# This is the most critical part of this specific solution. Palindrome problems often include spaces or punctuation (e.g., "A man, a plan, a canal: Panama").
#
# while l < r and not s[l].isalnum():
#     l += 1while l < r and not s[r].isalnum():
#     r -= 1
#
#
# * .isalnum(): This Python method returns True if a character is a letter (A-Z) or a number (0-9).
# * If the pointer lands on a space or a comma, the inner while loop simply pushes the pointer forward (or backward) until it hits a valid letter or number.
# * Why l < r inside these loops? To ensure that if a string is entirely symbols (like ".,.,"), the pointers don't run off the edge of the string and cause an error.
#
# ## 4. The Comparison (Lines 8-11)
#
# if s[l].lower() != s[r].lower():
#     return False
# l += 1
# r -= 1
#
#
# * .lower(): This makes the check case-insensitive. 'A' and 'a' will be treated as the same character.
# * The Check: If the character at the left doesn't match the character at the right, the function immediately stops and says False.
# * Movement: If they do match, we move both pointers one step closer to the center to check the next pair.
#
# ## 5. Success (Line 12)
#
# return True
#
# If the code manages to finish the entire while loop without ever hitting the return False statement, it means every character matched its mirror image. The string is a valid palindrome.
# ------------------------------
# ## Complexity Analysis
#
# * Time Complexity: $O(n)$
# Even though there are nested while loops, each character in the string is visited at most once by either the l or r pointer.
# * Space Complexity: $O(1)$
# The solution is very efficient because it doesn't create a new "cleaned" version of the string. It does everything in-place using only two integer variables (l and r).
#
# ## Example Trace: "A @ a"
#
#    1. l starts at 'A', r starts at 'a'.
#    2. l is alphanumeric. r is alphanumeric.
#    3. 'a' == 'a'? Yes. Move pointers.
#    4. l moves to ' ', r moves to '@'.
#    5. The inner loops skip ' ' and '@'.
#    6. l and r meet. The loop ends.
#    7. Result: True.
#
# ------------------------------
# Since this used Opposite Direction pointers, would you like to see how to solve a Same Direction pointer problem, like "Moving Zeros to the end of an array"?

# %% [markdown]
# This code uses the Fast and Slow Pointers technique (often called the "Tortoise and the Hare"). Unlike the palindrome example which moved pointers toward each other, these pointers move in the same direction but at different speeds.
# The goal is to find the middle node of a linked list in a single pass.
# ------------------------------
# ## 1. The Setup (Line 7)
#
# slow = fast = head
#
#
# * Both pointers start at the very first node (head).
# * In a linked list, you can't jump to an index like list[5]; you have to follow the "next" links.
#
# ## 2. The Loop & Movement (Lines 8–10)
#
# while fast and fast.next:
#     fast = fast.next.next
#     slow = slow.next
#
#
# * The "Hare" (fast): Moves two steps at a time.
# * The "Tortoise" (slow): Moves one step at a time.
# * The Condition: The loop keeps going as long as fast hasn't reached the end of the list and has a "next" node to jump over.
#
# ## 3. The Logic: Why it works
# Think of this like a race on a track:
#
# * If Runner A runs twice as fast as Runner B...
# * When Runner A crosses the finish line (the end of the list), Runner B will be exactly at the halfway point.
#
# By the time fast reaches the end, slow is guaranteed to be sitting on the middle node.
# ## 4. The Result (Line 11)
#
# return slow.val
#
# Once the loop breaks, the function returns the value stored in the slow node.
# ------------------------------
# ## Comparison: Odd vs. Even Lists
#
# * Odd Length (e.g., 5 nodes): fast will land exactly on the last node. slow will be on the 3rd node (the exact middle).
# * Even Length (e.g., 6 nodes): fast will move past the end to None. slow will land on the 4th node (the second of the two middle nodes).
#
# ## Efficiency
#
# * Time Complexity: $O(n)$ — You traverse the list only once.
# * Space Complexity: $O(1)$ — You only use two pointers, regardless of how long the list is. This is much better than copying the list into an array first!
#
# ------------------------------
# This "Fast and Slow" pattern is also the standard way to detect a cycle (loop) in a linked list. Would you like to see how a small tweak to this code can tell you if a list goes in a circle?

# %% [markdown]
# ![Screenshot 2026-04-06 220724.png](data:image/png;base64,...)

# %% [markdown]
# # **SLIDING WINDOW**

# %% [markdown]
# ![Screenshot 2026-04-07 102340.png](data:image/png;base64,...)

# %% [markdown]
# This code is a **template for the sliding window technique (fixed window size)** — a very important concept in DSA.
#
# Let’s break it down **step by step in beginner-friendly way** 👇
#
# ---
#
# ## 🔹 What is this code trying to do?
#
# It processes a list (`input`) by looking at **subarrays of size `window_size`** and keeps track of the **best result (`ans`)**.
#
# 👉 Example:
# If input = `[1,2,3,4,5]` and window_size = 3
# Windows will be:
#
# * `[1,2,3]`
# * `[2,3,4]`
# * `[3,4,5]`
#
# ---
#
# ## 🔹 Code Explanation
#
# ```python
# def sliding_window_fixed(input, window_size):
# ```
#
# 👉 Function takes:
#
# * `input`: list/array
# * `window_size`: size of the window
#
# ---
#
# ### 1. Initialize window
#
# ```python
# ans = window = input[0:window_size]
# ```
#
# 👉 Take the **first window**
# Example:
#
# ```
# input = [1,2,3,4,5]
# window_size = 3
#
# window = [1,2,3]
# ans = [1,2,3]
# ```
#
# ---
#
# ### 2. Loop through the rest
#
# ```python
# for right in range(window_size, len(input)):
# ```
#
# 👉 `right` moves forward step by step
# 👉 It represents the **new element entering the window**
#
# ---
#
# ### 3. Find the left element to remove
#
# ```python
# left = right - window_size
# ```
#
# 👉 This gives the index of the element leaving the window
#
# ---
#
# ### 4. Slide the window
#
# ```python
# remove input[left] from window
# append input[right] to window
# ```
#
# 👉 Two operations:
#
# * Remove old element (left side)
# * Add new element (right side)
#
# Example:
#
# ```
# Old window: [1,2,3]
# Remove 1 → [2,3]
# Add 4 → [2,3,4]
# ```
#
# ---
#
# ### 5. Update answer
#
# ```python
# ans = optimal(ans, window)
# ```
#
# 👉 This depends on the problem:
#
# * Max sum → compare sums
# * Min value → compare minimums
# * Longest substring → compare lengths
#
# 👉 `optimal()` means:
#
# > "Check if current window is better than previous answer"
#
# ---
#
# ### 6. Return result
#
# ```python
# return ans
# ```
#
# ---
#
# ## 🔹 Simple Example (Max Sum)
#
# ```python
# def optimal(ans, window):
#     return max(ans, sum(window))
# ```
#
# ---
#
# ## 🔹 Key Idea (VERY IMPORTANT)
#
# Instead of recalculating everything:
# ❌ Brute force → O(n * k)
# ✅ Sliding window → O(n)
#
# 👉 Because we **reuse previous work**
#
# ---
#
# ## 🔹 Visual Intuition
#
# ```
# [1,2,3,4,5]
#
# [1,2,3]
#    ↓
# [2,3,4]
#    ↓
# [3,4,5]
# ```
#
# Window **slides one step at a time**
#
# ---
#
# ## 🔹 When to use this?
#
# Use sliding window when:
#
# * Subarrays / substrings
# * Fixed size window
# * Continuous elements
# * Optimization (max/min/sum/etc.)
#
# ---
#
# ## 🔹 Real Interview Problems
#
# * Maximum sum subarray of size k
# * First negative number in every window
# * Longest substring without repeating chars (variation)
#
# ---
#
# If you want, I can:
# ✅ Give you 5 interview questions
# ✅ Or teach variable-size sliding window next (very important)

# %% [markdown]
# Great question — this is the **core line that confuses most beginners**, so let’s break it with a **real example step by step** 👇
#
# ---
#
# ## 🔹 Given
#
# ```python
# input = [10, 20, 30, 40, 50]
# window_size = 3
# ```
#
# 👉 First window:
#
# ```
# [10, 20, 30]
# ```
#
# ---
#
# ## 🔹 Loop starts
#
# ```python
# for right in range(window_size, len(input)):
# ```
#
# 👉 `right` starts from index `3`
#
# ---
#
# ## 🔹 Iteration 1
#
# ### Step 1: right = 3
#
# ```python
# left = right - window_size
# left = 3 - 3 = 0
# ```
#
# 👉 So:
#
# * `left = 0`
# * `input[left] = 10` (this will be removed)
# * `input[right] = 40` (this will be added)
#
# ---
#
# ### Window movement
#
# ```
# Old window: [10, 20, 30]
#
# Remove input[left] → remove 10
# New window: [20, 30]
#
# Add input[right] → add 40
# New window: [20, 30, 40]
# ```
#
# ---
#
# ## 🔹 Iteration 2
#
# ### Step 2: right = 4
#
# ```python
# left = 4 - 3 = 1
# ```
#
# 👉 So:
#
# * `left = 1`
# * `input[left] = 20` (remove)
# * `input[right] = 50` (add)
#
# ---
#
# ### Window movement
#
# ```
# Old window: [20, 30, 40]
#
# Remove 20 → [30, 40]
# Add 50 → [30, 40, 50]
# ```
#
# ---
#
# ## 🔹 Why `left = right - window_size` works
#
# 👉 It always points to the **element that is going out of the window**
#
# Think of it like this:
#
# ```
# Window size = 3
#
# Index:   0   1   2   3   4
# Array:  10  20  30  40  50
#
# Step 1:
# Window → [0,1,2]
# Next right = 3
# Left = 3 - 3 = 0  ✅ remove index 0
#
# Step 2:
# Window → [1,2,3]
# Next right = 4
# Left = 4 - 3 = 1  ✅ remove index 1
# ```
#
# ---
#
# ## 🔹 Simple Rule to Remember
#
# 👉 `right` = new element entering
# 👉 `left` = old element leaving
#
# ```python
# left = right - window_size
# ```
#
# ✔ Keeps window size constant
# ✔ Moves window forward by 1
#
# ---
#
# ## 🔹 Visual Summary
#
# ```
# [10, 20, 30]   → remove 10, add 40 → [20, 30, 40]
# [20, 30, 40]   → remove 20, add 50 → [30, 40, 50]
# ```
#
# ---
#
# ## 🔥 One-line intuition
#
# 👉 “`left` is always the element that falls out when the window moves forward”
#
# ---
#
# If you want next:
# I can show you **how to implement this with sum optimization (O(n))** — that’s what interviewers actually expect 🚀

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Perfect — this is the **real implementation of sliding window (max sum of subarray of size k)**. I’ll explain it **step-by-step just like before** 👇
#
# ---
#
# ## 🔹 What this code does
#
# 👉 Finds the **maximum sum of any subarray of size `k`**
#
# ---
#
# ## 🔹 Example to understand
#
# ```python
# nums = [10, 20, 30, 40, 50]
# k = 3
# ```
#
# Subarrays:
#
# * `[10,20,30] → sum = 60`
# * `[20,30,40] → sum = 90`
# * `[30,40,50] → sum = 120` ✅ answer
#
# ---
#
# ## 🔹 Code Breakdown
#
# ---
#
# ### 1. Function start
#
# ```python
# def subarray_sum_fixed(nums: list[int], k: int) -> int:
# ```
#
# 👉 Takes:
#
# * `nums` → list of numbers
# * `k` → window size
#
# ---
#
# ### 2. Create first window sum
#
# ```python
# window_sum = 0
# for i in range(k):
#     window_sum += nums[i]
# ```
#
# 👉 Add first `k` elements
#
# Example:
#
# ```python
# window_sum = 10 + 20 + 30 = 60
# ```
#
# ---
#
# ### 3. Store initial answer
#
# ```python
# largest = window_sum
# ```
#
# 👉 First window is our starting answer
#
# ---
#
# ## 🔹 Now the Sliding Starts 🔥
#
# ```python
# for right in range(k, len(nums)):
# ```
#
# 👉 `right` = new element entering the window
#
# ---
#
# ## 🔹 Iteration 1
#
# ### right = 3
#
# ```python
# left = right - k
# left = 3 - 3 = 0
# ```
#
# 👉 Remove `nums[0] = 10`
# 👉 Add `nums[3] = 40`
#
# ---
#
# ### Update sum
#
# ```python
# window_sum -= nums[left]   # remove 10
# window_sum += nums[right]  # add 40
# ```
#
# ```python
# window_sum = 60 - 10 + 40 = 90
# ```
#
# ---
#
# ### Update max
#
# ```python
# largest = max(largest, window_sum)
# largest = max(60, 90) = 90
# ```
#
# ---
#
# ## 🔹 Iteration 2
#
# ### right = 4
#
# ```python
# left = 4 - 3 = 1
# ```
#
# 👉 Remove `20`, Add `50`
#
# ---
#
# ### Update sum
#
# ```python
# window_sum = 90 - 20 + 50 = 120
# ```
#
# ---
#
# ### Update max
#
# ```python
# largest = max(90, 120) = 120
# ```
#
# ---
#
# ## 🔹 Final Answer
#
# ```python
# return largest  # 120
# ```
#
# ---
#
# ## 🔹 Why this is efficient ⚡
#
# Instead of:
#
# ```python
# sum([20,30,40])  # recalculating
# ```
#
# We do:
#
# ```python
# window_sum = previous_sum - old + new
# ```
#
# 👉 Saves time → **O(n)** instead of **O(n*k)**
#
# ---
#
# ## 🔹 Visual Flow
#
# ```text
# [10,20,30] → sum = 60
#    ↓
# [20,30,40] → sum = 90
#    ↓
# [30,40,50] → sum = 120 ✅
# ```
#
# ---
#
# ## 🔹 Key Line (IMPORTANT)
#
# ```python
# window_sum = window_sum - nums[left] + nums[right]
# ```
#
# 👉 This is the **heart of sliding window**
#
# ---
#
# ## 🔹 Input/Output part
#
# ```python
# if __name__ == "__main__":
# ```
#
# 👉 Means: run only when file is executed
#
# ```python
# nums = [int(x) for x in input().split()]
# k = int(input())
# ```
#
# Example input:
#
# ```text
# 10 20 30 40 50
# 3
# ```
#
# ---
#
# ## 🔥 One-line intuition
#
# 👉 “Remove the old element, add the new element, update max”
#
# ---
#
# If you want next:
# I can teach you
# ✅ Variable sliding window (MOST IMPORTANT for interviews)
# ✅ Or give you 5 real interview problems with solutions 🚀

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nice — this is the **next level of sliding window** 🔥
# 👉 **Variable-size sliding window** (very important for interviews)
#
# ---
#
# ## 🔹 What this code does
#
# 👉 Finds the **length of the longest substring without repeating characters**
#
# ---
#
# ## 🔹 Example
#
# ```python
# s = "abcabcbb"
# ```
#
# Valid substrings:
#
# * `"abc"` → length = 3 ✅
# * `"abca"` ❌ (repeat)
#
# 👉 Answer = **3**
#
# ---
#
# ## 🔹 Code Breakdown
#
# ---
#
# ### 1. Import
#
# ```python
# from collections import defaultdict
# ```
#
# 👉 `defaultdict(int)` means:
#
# * If key doesn’t exist → default value = 0
#
# ---
#
# ### 2. Function start
#
# ```python
# def longest_substring_without_repeating_characters(s: str) -> int:
# ```
#
# ---
#
# ### 3. Initialize variables
#
# ```python
# longest = 0
# l = 0
# counter = defaultdict(int)
# ```
#
# 👉 `l` → left pointer
# 👉 `r` → right pointer (we’ll loop it)
# 👉 `counter` → stores frequency of characters
#
# ---
#
# ## 🔹 Main Loop
#
# ```python
# for r in range(len(s)):
# ```
#
# 👉 Expand window to the right
#
# ---
#
# ## 🔹 Step-by-step Example
#
# Let’s take:
#
# ```python
# s = "abcabcbb"
# ```
#
# ---
#
# ### 🟢 Step 1: r = 0 ('a')
#
# ```python
# counter['a'] += 1
# ```
#
# Window:
#
# ```
# "a"
# ```
#
# ✔ No duplicates → valid
#
# ```python
# longest = max(0, 1) = 1
# ```
#
# ---
#
# ### 🟢 Step 2: r = 1 ('b')
#
# Window:
#
# ```
# "ab"
# ```
#
# ✔ Valid
#
# ```python
# longest = 2
# ```
#
# ---
#
# ### 🟢 Step 3: r = 2 ('c')
#
# Window:
#
# ```
# "abc"
# ```
#
# ✔ Valid
#
# ```python
# longest = 3
# ```
#
# ---
#
# ### 🔴 Step 4: r = 3 ('a')
#
# Now:
#
# ```python
# counter['a'] = 2 ❌ duplicate
# ```
#
# ---
#
# ## 🔥 Shrink window (VERY IMPORTANT PART)
#
# ```python
# while counter[s[r]] > 1:
#     counter[s[l]] -= 1
#     l += 1
# ```
#
# 👉 Move `l` until no duplicates
#
# ---
#
# ### Fixing duplicate
#
# Window before fixing:
#
# ```
# "abca"
# ```
#
# Steps:
#
# * Remove `a` at left
# * Move `l`
#
# Now window becomes:
#
# ```
# "bca"
# ```
#
# ✔ Valid again
#
# ---
#
# ### Update longest
#
# ```python
# longest = max(3, 3) = 3
# ```
#
# ---
#
# ## 🔁 Continue same process
#
# Eventually:
#
# ```
# Final answer = 3
# ```
#
# ---
#
# ## 🔹 Key Idea (CORE CONCEPT)
#
# 👉 Expand with `r`
# 👉 Shrink with `l` when invalid
#
# ---
#
# ## 🔹 Most Important Lines
#
# ### Add character
#
# ```python
# counter[s[r]] += 1
# ```
#
# ---
#
# ### Check duplicate
#
# ```python
# while counter[s[r]] > 1:
# ```
#
# 👉 Means:
#
# > “Current character is repeated”
#
# ---
#
# ### Shrink window
#
# ```python
# counter[s[l]] -= 1
# l += 1
# ```
#
# 👉 Remove left character until valid
#
# ---
#
# ### Update answer
#
# ```python
# longest = max(longest, r - l + 1)
# ```
#
# 👉 Window length = `r - l + 1`
#
# ---
#
# ## 🔹 Visual Intuition
#
# ```text
# a b c a b c b b
#       ↑ duplicate 'a'
#
# Shrink → remove left 'a'
#
# Now:
# b c a  ✔ valid again
# ```
#
# ---
#
# ## 🔥 Fixed vs Variable Window
#
# | Type     | Size     | Example           |
# | -------- | -------- | ----------------- |
# | Fixed    | Constant | Max sum of size k |
# | Variable | Changes  | Longest substring |
#
# ---
#
# ## 🔥 One-line intuition
#
# 👉 “Expand until invalid, shrink until valid, track max”
#
# ---
#
# ## 🔥 Why this is powerful
#
# This pattern solves:
#
# * Longest substring without repeating chars
# * Longest substring with k distinct chars
# * Minimum window substring (hard)
# * Many LeetCode questions
#
# ---
#
# If you want next:
# I can give you
# ✅ 5 interview questions on this pattern
# ✅ OR teach **minimum window substring (FAANG level)** 🚀

# %% [markdown]
# This is the **MOST IMPORTANT part** of the variable sliding window 🔥
# Let’s break it in a **very simple way** 👇
#
# ---
#
# ## 🔹 What this code means
#
# ```python
# while counter[s[r]] > 1:
#     counter[s[l]] -= 1
#     l += 1
# ```
#
# 👉 It means:
#
# > “If the current character is repeated, keep removing characters from the left until it becomes unique again.”
#
# ---
#
# ## 🔹 Why do we need this?
#
# We want:
# 👉 **No repeating characters in the window**
#
# So whenever a duplicate appears → we must **fix the window**
#
# ---
#
# ## 🔹 Step-by-step Example
#
# ```python
# s = "abca"
# ```
#
# We are at:
#
# ```text
# Window = "abca"
#             ↑ r
# ```
#
# Now:
#
# ```python
# counter['a'] = 2 ❌ duplicate
# ```
#
# ---
#
# ## 🔥 Now this loop runs
#
# ```python
# while counter[s[r]] > 1:
# ```
#
# 👉 Since `'a'` appears twice → condition is TRUE
#
# ---
#
# ### 🟢 First iteration
#
# ```python
# counter[s[l]] -= 1
# l += 1
# ```
#
# 👉 `l = 0` → character = `'a'`
#
# So:
#
# ```python
# counter['a'] -= 1   → now becomes 1
# l = 1
# ```
#
# ---
#
# ### ✅ Now window becomes
#
# ```text
# "bca"
# ```
#
# ✔ No duplicates anymore
#
# ---
#
# ### Loop stops
#
# Because:
#
# ```python
# counter['a'] == 1 ✅
# ```
#
# ---
#
# ## 🔹 What actually happened?
#
# | Step            | Action             |
# | --------------- | ------------------ |
# | Duplicate found | `'a'`              |
# | Start shrinking | from left          |
# | Remove `'a'`    | fixed duplicate    |
# | Stop shrinking  | window valid again |
#
# ---
#
# ## 🔹 Visual Understanding
#
# ```text
# Before:
# a b c a
# ↑     ↑
# l     r
#
# After removing left:
#   b c a
#   ↑   ↑
#   l   r
# ```
#
# ---
#
# ## 🔹 Key Insight (VERY IMPORTANT)
#
# 👉 We **only shrink until the problem is fixed**
#
# NOT fully reset
# NOT restart
#
# Just enough to make it valid again ✔
#
# ---
#
# ## 🔥 One-line intuition
#
# 👉 “Remove characters from left until duplicate is gone”
#
# ---
#
# ## 🔹 Why `while` and not `if`?
#
# Because sometimes:
#
# * There can be **multiple duplicates**
# * Or removing one char is not enough
#
# 👉 So we keep shrinking **until valid**
#
# ---
#
# ## 🔥 Real meaning in plain English
#
# ```text
# "Hey, this character is repeated.
# Let me move left forward and remove characters
# until it's no longer repeated."
# ```
#
# ---
#
# ## 🚀 This is THE pattern
#
# Once you understand this, you can solve:
#
# * Longest substring problems
# * Sliding window with conditions
# * Hard LeetCode questions
#
# ---
#
# If you want:
# I can give you a **visual dry run animation style** OR
# a **hard problem using same logic** (interview level)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Great — now this is **Binary Search (very important DSA topic)** 🔥
# I’ll explain it in the **same simple step-by-step way** 👇
#
# ---
#
# ## 🔹 What this code does
#
# 👉 Finds the **first occurrence of `True`** in a boolean array
#
# ---
#
# ## 🔹 Example
#
# ```python
# arr = [False, False, False, True, True, True]
# ```
#
# 👉 Answer = **index 3** (first `True`)
#
# ---
#
# ## 🔹 Key Idea
#
# 👉 Array looks like this:
#
# ```text
# F F F F T T T
#         ↑
#     boundary
# ```
#
# We need to find the **boundary where False → True**
#
# ---
#
# ## 🔹 Code Breakdown
#
# ---
#
# ### 1. Initialize pointers
#
# ```python
# left, right = 0, len(arr) - 1
# boundary_index = -1
# ```
#
# 👉 `left` = start
# 👉 `right` = end
# 👉 `boundary_index` = stores answer
#
# ---
#
# ## 🔹 Main Loop
#
# ```python
# while left <= right:
# ```
#
# 👉 Keep searching until pointers cross
#
# ---
#
# ## 🔹 Find middle
#
# ```python
# mid = (left + right) // 2
# ```
#
# 👉 Check middle element
#
# ---
#
# ## 🔹 Step-by-step Example
#
# ```python
# arr = [F, F, F, T, T, T]
# index =  0  1  2  3  4  5
# ```
#
# ---
#
# ## 🟢 Iteration 1
#
# ```python
# mid = (0 + 5) // 2 = 2
# arr[mid] = False
# ```
#
# 👉 Means:
#
# * Boundary is on the **right side**
#
# ```python
# left = mid + 1 = 3
# ```
#
# ---
#
# ## 🟢 Iteration 2
#
# ```python
# mid = (3 + 5) // 2 = 4
# arr[mid] = True
# ```
#
# 👉 Found a `True`
# BUT maybe there's an earlier `True`
#
# ```python
# boundary_index = 4
# right = mid - 1 = 3
# ```
#
# ---
#
# ## 🟢 Iteration 3
#
# ```python
# mid = (3 + 3) // 2 = 3
# arr[mid] = True
# ```
#
# 👉 Better answer
#
# ```python
# boundary_index = 3
# right = 2
# ```
#
# ---
#
# ## ❌ Loop ends
#
# ```python
# left = 3, right = 2 → stop
# ```
#
# ---
#
# ## 🔹 Final Answer
#
# ```python
# return boundary_index  # 3
# ```
#
# ---
#
# ## 🔹 Why this works
#
# 👉 Every time we see:
#
# * `False` → go RIGHT
# * `True` → go LEFT (to find first occurrence)
#
# ---
#
# ## 🔥 Key Lines (VERY IMPORTANT)
#
# ### Case 1: Found True
#
# ```python
# if arr[mid]:
#     boundary_index = mid
#     right = mid - 1
# ```
#
# 👉 Store answer and try to find earlier one
#
# ---
#
# ### Case 2: Found False
#
# ```python
# else:
#     left = mid + 1
# ```
#
# 👉 Move right
#
# ---
#
# ## 🔹 Visual Intuition
#
# ```text
# F F F T T T
#       ↑ mid
#
# Move right →
#
#       F F F T T T
#           ↑ mid
#
# Found True → move left ←
# ```
#
# ---
#
# ## 🔥 One-line intuition
#
# 👉 “Find True, but keep searching left for earlier True”
#
# ---
#
# ## 🔹 Time Complexity
#
# ```text
# O(log n) 🚀
# ```
#
# Much faster than linear search
#
# ---
#
# ## 🔥 Pattern Name
#
# 👉 **Binary Search on Answer / Boundary Search**
#
# ---
#
# ## 🔹 Where this is used
#
# * First occurrence problems
# * Lower bound / upper bound
# * Searching in sorted arrays
# * Optimization problems
#
# ---
#
# ## 🚀 If you want next
#
# I can teach:
# ✅ Lower Bound & Upper Bound (VERY IMPORTANT)
# ✅ OR Binary Search interview problems (Google level)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nice — this is a **very important binary search pattern** 🔥
# 👉 Finding the **minimum element in a rotated sorted array**
#
# I’ll explain it **step-by-step like before** 👇
#
# ---
#
# ## 🔹 What is a rotated sorted array?
#
# 👉 A sorted array that has been rotated
#
# ### Example:
#
# ```python
# arr = [4, 5, 6, 7, 0, 1, 2]
# ```
#
# Originally:
#
# ```text
# [0, 1, 2, 4, 5, 6, 7]
# ```
#
# Rotated:
#
# ```text
# [4, 5, 6, 7, 0, 1, 2]
#                 ↑ smallest
# ```
#
# 👉 We need to find **index of smallest element (0)**
#
# ---
#
# ## 🔹 Key Idea
#
# 👉 Array is split into **two sorted parts**
#
# ```text
# [4, 5, 6, 7] [0, 1, 2]
#   bigger part   smaller part
# ```
#
# 👉 The smallest element is the **boundary**
#
# ---
#
# ## 🔹 Code Breakdown
#
# ---
#
# ### 1. Initialize
#
# ```python
# left, right = 0, len(arr) - 1
# boundary_index = -1
# ```
#
# ---
#
# ## 🔹 Main Loop
#
# ```python
# while left <= right:
# ```
#
# ---
#
# ### 2. Find mid
#
# ```python
# mid = (left + right) // 2
# ```
#
# ---
#
# ## 🔥 Key Logic (MOST IMPORTANT)
#
# ```python
# if arr[mid] <= arr[-1]:
# ```
#
# 👉 Compare with **last element**
#
# ---
#
# ## 🔹 Why compare with last element?
#
# 👉 Because:
#
# | Condition             | Meaning                            |
# | --------------------- | ---------------------------------- |
# | `arr[mid] <= arr[-1]` | mid is in **right (smaller) half** |
# | `arr[mid] > arr[-1]`  | mid is in **left (bigger) half**   |
#
# ---
#
# ## 🔹 Step-by-step Example
#
# ```python
# arr = [4, 5, 6, 7, 0, 1, 2]
# index =  0  1  2  3  4  5  6
# ```
#
# ---
#
# ## 🟢 Iteration 1
#
# ```python
# mid = (0 + 6) // 2 = 3
# arr[mid] = 7
# arr[-1] = 2
# ```
#
# 👉 `7 > 2` → LEFT part
#
# ```python
# left = mid + 1 = 4
# ```
#
# ---
#
# ## 🟢 Iteration 2
#
# ```python
# mid = (4 + 6) // 2 = 5
# arr[mid] = 1
# ```
#
# 👉 `1 <= 2` → RIGHT part ✅
#
# ```python
# boundary_index = 5
# right = mid - 1 = 4
# ```
#
# ---
#
# ## 🟢 Iteration 3
#
# ```python
# mid = (4 + 4) // 2 = 4
# arr[mid] = 0
# ```
#
# 👉 `0 <= 2` → RIGHT part ✅
#
# ```python
# boundary_index = 4
# right = 3
# ```
#
# ---
#
# ## ❌ Loop ends
#
# ```python
# left = 4, right = 3 → stop
# ```
#
# ---
#
# ## 🔹 Final Answer
#
# ```python
# return boundary_index  # 4
# ```
#
# 👉 Index of minimum element ✅
#
# ---
#
# ## 🔹 Visual Intuition
#
# ```text
# [4, 5, 6, 7 | 0, 1, 2]
#                ↑
#            smallest
# ```
#
# We are basically finding:
# 👉 **First element of right half**
#
# ---
#
# ## 🔥 Core Pattern
#
# 👉 Same as previous problem (boundary search)
#
# | Condition         | Move     |
# | ----------------- | -------- |
# | mid in right half | go LEFT  |
# | mid in left half  | go RIGHT |
#
# ---
#
# ## 🔹 Key Lines
#
# ### Case 1: In right half
#
# ```python
# if arr[mid] <= arr[-1]:
#     boundary_index = mid
#     right = mid - 1
# ```
#
# 👉 Store answer, search left
#
# ---
#
# ### Case 2: In left half
#
# ```python
# else:
#     left = mid + 1
# ```
#
# 👉 Ignore left part, go right
#
# ---
#
# ## 🔥 One-line intuition
#
# 👉 “Find the first element that is ≤ last element”
#
# ---
#
# ## 🔹 Time Complexity
#
# ```text
# O(log n) 🚀
# ```
#
# ---
#
# ## 🔥 Real Interview Use
#
# This pattern is used in:
#
# * Find minimum in rotated array
# * Search in rotated array
# * Peak element problems
#
# ---
#
# ## 🚀 If you want next
#
# I can teach:
# ✅ Search element in rotated array (next level 🔥)
# ✅ OR give you FAANG-level binary search problems

# %% [markdown]
# # **BFS**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Perfect — now you’ve reached **Trees + BFS (Breadth First Search)** 🔥
# I’ll explain it **step-by-step in the same beginner-friendly way** 👇
#
# ---
#
# ## 🔹 What is happening here?
#
# 👉 We are **traversing a tree level by level**
#
# 👉 This method is called:
# 🔥 **BFS (Breadth First Search)**
#
# ---
#
# ## 🔹 Tree Example (from image)
#
# ```
#         20
#        /  \
#      14    24
#     / \    / \
#   11  16  27  29
# ```
#
# ---
#
# ## 🔹 Goal of BFS
#
# 👉 Visit nodes **level by level**
#
# Order:
#
# ```text
# 20 → 14 → 24 → 11 → 16 → 27 → 29
# ```
#
# ---
#
# ## 🔹 Code Breakdown
#
# ---
#
# ### 1. Function start
#
# ```python
# def bfs(root):
# ```
#
# 👉 Start from root node
#
# ---
#
# ### 2. Create queue
#
# ```python
# queue = deque([root])
# ```
#
# 👉 Queue = FIFO (First In First Out)
#
# 👉 Initially:
#
# ```text
# queue = [20]
# ```
#
# ---
#
# ## 🔥 Why queue?
#
# 👉 Because BFS works **level-wise**
#
# ---
#
# ## 🔹 Main Loop
#
# ```python
# while len(queue) > 0:
# ```
#
# 👉 Run until queue is empty
#
# ---
#
# ## 🔹 Step-by-step Execution
#
# ---
#
# ### 🟢 Step 1
#
# ```python
# node = queue.popleft()
# ```
#
# 👉 Remove from front
#
# ```text
# node = 20
# queue = []
# ```
#
# ---
#
# ### Add children
#
# ```python
# for child in node.children:
#     queue.append(child)
# ```
#
# 👉 Add:
#
# ```text
# queue = [14, 24]
# ```
#
# ---
#
# ## 🟢 Step 2
#
# ```text
# node = 14
# queue = [24]
# ```
#
# Add children:
#
# ```text
# queue = [24, 11, 16]
# ```
#
# ---
#
# ## 🟢 Step 3
#
# ```text
# node = 24
# queue = [11, 16]
# ```
#
# Add children:
#
# ```text
# queue = [11, 16, 27, 29]
# ```
#
# ---
#
# ## 🟢 Continue...
#
# ```text
# node = 11 → no children
# node = 16 → no children
# node = 27 → no children
# node = 29 → no children
# ```
#
# ---
#
# ## 🔹 Goal Check (IMPORTANT)
#
# ```python
# if is_goal(child):
#     return FOUND(child)
# ```
#
# 👉 While traversing:
#
# * If we find target → stop immediately
#
# ---
#
# ## 🔹 Final Return
#
# ```python
# return NOT_FOUND
# ```
#
# 👉 If nothing matched
#
# ---
#
# ## 🔹 Visual Flow
#
# ```text
# Queue flow:
#
# [20]
#  ↓
# [14, 24]
#  ↓
# [24, 11, 16]
#  ↓
# [11, 16, 27, 29]
#  ↓
# []
# ```
#
# ---
#
# ## 🔥 Key Idea
#
# 👉 Use **queue to explore level by level**
#
# ---
#
# ## 🔹 BFS vs DFS
#
# | BFS            | DFS                  |
# | -------------- | -------------------- |
# | Level by level | Goes deep first      |
# | Uses Queue     | Uses Stack/Recursion |
#
# ---
#
# ## 🔥 One-line intuition
#
# 👉 “Take from front, add children to back”
#
# ---
#
# ## 🔹 Where BFS is used
#
# * Shortest path (unweighted graph)
# * Tree traversal
# * Level order traversal
# * Finding nearest node
#
# ---
#
# ## 🔥 Time Complexity
#
# ```text
# O(n)
# ```
#
# ---
#
# ## 🚀 If you want next
#
# I can teach:
# ✅ DFS (Depth First Search)
# ✅ OR Binary Tree questions (VERY IMPORTANT for interviews)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Nice — this is **BFS on a Graph** 🔥
# Very similar to tree BFS, but with one extra thing:
# 👉 **we must track visited nodes** (because graphs can have cycles)
#
# I’ll explain it **step-by-step same as before** 👇
#
# ---
#
# ## 🔹 What this code does
#
# 👉 Traverses a **graph level by level** using BFS
# 👉 Prints nodes in BFS order
#
# ---
#
# ## 🔹 Example Graph
#
# ```text
# Graph (adjacency list):
#
# A → B, C
# B → D
# C → E
# D →
# E →
# ```
#
# ---
#
# ## 🔹 BFS Output (starting from A)
#
# ```text
# A B C D E
# ```
#
# ---
#
# ## 🔹 Code Breakdown
#
# ---
#
# ### 1. Function
#
# ```python
# def bfs(graph, node):
# ```
#
# 👉 `graph` = adjacency list
# 👉 `node` = starting node
#
# ---
#
# ## 🔹 2. Initialize
#
# ```python
# visited = []
# queue = []
# ```
#
# 👉 `visited` → to avoid revisiting nodes
# 👉 `queue` → for BFS
#
# ---
#
# ### Add starting node
#
# ```python
# visited.append(node)
# queue.append(node)
# ```
#
# ```text
# visited = [A]
# queue = [A]
# ```
#
# ---
#
# ## 🔥 Main Loop
#
# ```python
# while queue:
# ```
#
# 👉 Run until queue is empty
#
# ---
#
# ## 🔹 Step-by-step Execution
#
# ---
#
# ### 🟢 Step 1
#
# ```python
# s = queue.pop(0)
# print(s)
# ```
#
# 👉 Remove from front
#
# ```text
# s = A
# queue = []
# ```
#
# ---
#
# ## 🔴 Key Part (IMPORTANT)
#
# ```python
# for n in graph[s]:
# ```
#
# 👉 Loop through neighbors of current node
#
# ---
#
# ### For A:
#
# ```text
# graph[A] = [B, C]
# ```
#
# ---
#
# ### Add neighbors
#
# ```python
# if n not in visited:
#     visited.append(n)
#     queue.append(n)
# ```
#
# ```text
# visited = [A, B, C]
# queue = [B, C]
# ```
#
# ---
#
# ## 🟢 Step 2
#
# ```text
# s = B
# queue = [C]
# ```
#
# Neighbors:
#
# ```text
# D
# ```
#
# Add:
#
# ```text
# visited = [A, B, C, D]
# queue = [C, D]
# ```
#
# ---
#
# ## 🟢 Step 3
#
# ```text
# s = C
# queue = [D]
# ```
#
# Neighbors:
#
# ```text
# E
# ```
#
# Add:
#
# ```text
# visited = [A, B, C, D, E]
# queue = [D, E]
# ```
#
# ---
#
# ## 🟢 Continue
#
# ```text
# s = D → no new nodes
# s = E → no new nodes
# ```
#
# ---
#
# ## 🔹 Final Output
#
# ```text
# A B C D E
# ```
#
# ---
#
# ## 🔥 Key Idea
#
# 👉 Visit node
# 👉 Add its neighbors
# 👉 Avoid revisiting
#
# ---
#
# ## 🔥 Most Important Lines
#
# ### 1. Explore neighbors
#
# ```python
# for n in graph[s]:
# ```
#
# 👉 Get all connected nodes
#
# ---
#
# ### 2. Avoid cycles
#
# ```python
# if n not in visited:
# ```
#
# 👉 VERY IMPORTANT in graphs
#
# ---
#
# ### 3. Add to queue
#
# ```python
# queue.append(n)
# ```
#
# 👉 Process later (FIFO)
#
# ---
#
# ## 🔹 Visual Flow
#
# ```text
# Start:
# [A]
#
# → Visit A → add B, C
# [B, C]
#
# → Visit B → add D
# [C, D]
#
# → Visit C → add E
# [D, E]
#
# → Visit D → nothing
# [E]
#
# → Visit E → nothing
# []
# ```
#
# ---
#
# ## 🔥 BFS vs Tree BFS
#
# | Tree              | Graph              |
# | ----------------- | ------------------ |
# | No cycles         | Can have cycles    |
# | No visited needed | Must track visited |
#
# ---
#
# ## 🔥 One-line intuition
#
# 👉 “Visit node → add neighbors → don’t revisit”
#
# ---
#
# ## 🔹 Time Complexity
#
# ```text
# O(V + E)
# ```
#
# 👉 V = nodes, E = edges
#
# ---
#
# ## 🚀 If you want next
#
# I can teach:
# ✅ DFS for graphs
# ✅ OR shortest path using BFS (VERY IMPORTANT 🚀)

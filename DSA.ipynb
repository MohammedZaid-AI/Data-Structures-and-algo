# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedZaid-AI/Data-Structures-and-algo/blob/main/DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n="hello"

# %%
freq={}

# %%
count=1

# %%
freq[i]=count

# %%
for i in n:
  if i in freq:
    freq[i]=
  else:
    freq[i]=count

# %%
freq
# Out:
# {'o': 1, 'h': 1, 'e': 1, 'l': 1}
